# %% [markdown]
# ## Read data

# %%
import pandas as pd
from neo4j import GraphDatabase

# %%
data = pd.read_json('../Data/ScrapedData.json')

# %%
data.head()
# Out:
#                          name                           url redirected_urls  \
# 0                Faceless Men            /wiki/Faceless_Men            None
# 1      Old Gods of the Forest  /wiki/Old_Gods_of_the_Forest            None
# 2  R'hllor, the Lord of Light               /wiki/R%27hllor            None
# 3                 Drowned God             /wiki/Drowned_God            None
# 4                   Unsullied               /wiki/Unsullied            None
#
#                                                edges  \
# 0  [{'Source': '/wiki/Faceless_Men', 'Label': 'Se...
# 1  [{'Source': '/wiki/Old_Gods_of_the_Forest', 'L...
# 2  [{'Source': '/wiki/R%27hllor', 'Label': 'Clerg...
# 3  [{'Source': '/wiki/Drowned_God', 'Label': 'Cle...
# 4  [{'Source': '/wiki/Unsullied', 'Label': 'Seaso...
#
#                                           properties    status  \
# 0  [Season(s), Mentioned in, Status, Type, Notabl...  [Active]
# 1           [Type, Clergy, Location, Leader, Center]       NaN
# 2  [Type, Clergy, Location, Leader, Notable Membe...       NaN
# 3  [Type, Clergy, Location, Notable Members, Form...       NaN
# 4  [Season(s), Mentioned in, Status, Type, Allegi...  [Active]
#
#                                   got_type     node_type
# 0         [Religious cult, Assassin guild]  Organization
# 1  [Polytheistic, Animistic, Henotheistic]  Organization
# 2                               [Ditheism]  Organization
# 3                          [Monolatristic]  Organization
# 4                         [Spear infantry]  Organization

# %%
data.node_type.unique()
# Out:
# array(['Organization', 'Person', 'Event', 'Episode', 'Animal', 'Location',
#        'HistoriesNLore', 'Weapon', 'House', 'PersonType', 'Religion',
#        'Season'], dtype=object)

# %% [markdown]
# ## Extract edges

# %%
# Create a dictionary for redirected_urls

red = data[data.redirected_urls.isnull() == False]
red[red.redirected_urls.apply(len) == 1]
redirect_dict = {}
red.redirected_urls = red.redirected_urls.apply(lambda x: x[0])

redirect_dict = dict(zip(red.redirected_urls,red.url))
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5920\2586151159.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   red.redirected_urls = red.redirected_urls.apply(lambda x: x[0])

# %%
edges = []
def process_edges(arr):    
    for json in arr:
        edges.append([json['Source'], json['Label'], json['Target']])
    pass

data.edges.apply(process_edges)
dfe = pd.DataFrame(edges, columns=['Source', 'Label', 'Target'])

dfe.head()
# Out:
#                Source            Label                 Target
# 0  /wiki/Faceless_Men        Season(s)         /wiki/Season_2
# 1  /wiki/Faceless_Men        Season(s)         /wiki/Season_5
# 2  /wiki/Faceless_Men        Season(s)         /wiki/Season_6
# 3  /wiki/Faceless_Men     Mentioned in  /wiki/Valar_Morghulis
# 4  /wiki/Faceless_Men  Notable Members   /wiki/Jaqen_H%27ghar

# %%
# check is all source is in nodes data
print('No. of unique Sources in edges data = ' + str(dfe.Source.unique().__len__()))
print('No. of unique nodes in nodes data = ' + str(data.url.unique().__len__()))

print('No. of nodes with 0 outgoing edges = ')
data[data.edges.apply(len) == 0]
# Out:
# No. of unique Sources in edges data = 2190
# No. of unique nodes in nodes data = 2192
# No. of nodes with 0 outgoing edges =
#               name                 url redirected_urls edges  \
# 416    House Wells   /wiki/House_Wells            None    []
# 1641  Black Friday  /wiki/Black_Friday            None    []
#
#                             properties status got_type node_type
# 416                                 []    NaN      NaN     House
# 1641  [Beginning, End, Place, Outcome]    NaN      NaN     Event

# %% [markdown]
# ## Remove edges where target node is not a valid node

# %%
# remove edges where target not in nodes data
print('No. of unique Target nodes in edges data(before) = ' + str(dfe.Target.unique().__len__()))

valid_nodes = set(data.url)

def get_redirected_target(url):
    if url in valid_nodes:
        return url
    elif url in redirect_dict.keys():
        return redirect_dict[url]
    else:
        return None

dfe['Target'] = dfe.Target.apply(get_redirected_target)
dfe[dfe.Target.isnull()]

print('No. of unique Target nodes in edges data(after)  = ' + str(dfe.Target.unique().__len__()))
# remove all None target nodes
# Edges is not ready

dfe = dfe[dfe.Target.isnull() == False]

dfe.head()
# Out:
# No. of unique Target nodes in edges data(before) = 2877
# No. of unique Target nodes in edges data(after)  = 1560
#                Source            Label                 Target
# 0  /wiki/Faceless_Men        Season(s)         /wiki/Season_2
# 1  /wiki/Faceless_Men        Season(s)         /wiki/Season_5
# 2  /wiki/Faceless_Men        Season(s)         /wiki/Season_6
# 3  /wiki/Faceless_Men     Mentioned in  /wiki/Valar_Morghulis
# 4  /wiki/Faceless_Men  Notable Members   /wiki/Jaqen_H%27ghar

# %% [markdown]
# ## Process data- remove 'wiki' & commas

# %%
print('remove /wiki/ part from the urls-')
dfe.Source = dfe.Source.apply(lambda x: x[6:])
dfe.Target = dfe.Target.apply(lambda x: x[6:])
data.url = data.url.apply(lambda x: x[6:])
# Out:
# remove /wiki/ part from the urls-

# %%
#replace comma with semi-colon before writing to csv
def get_formatted_value(arr):
    if isinstance(arr, list) and len(arr) > 0:
        return '; '.join(arr).replace(',', '-')
    return None
data.got_type = data.got_type.apply(get_formatted_value)
data.status = data.status.apply(get_formatted_value)

# %%
data.drop(['edges', 'properties', 'redirected_urls'], axis=1, inplace=True)

data.head()
# Out:
#                          name                     url  status  \
# 0                Faceless Men            Faceless_Men  Active
# 1      Old Gods of the Forest  Old_Gods_of_the_Forest    None
# 2  R'hllor, the Lord of Light               R%27hllor    None
# 3                 Drowned God             Drowned_God    None
# 4                   Unsullied               Unsullied  Active
#
#                                 got_type     node_type
# 0         Religious cult; Assassin guild  Organization
# 1  Polytheistic; Animistic; Henotheistic  Organization
# 2                               Ditheism  Organization
# 3                          Monolatristic  Organization
# 4                         Spear infantry  Organization

# %% [markdown]
# ## Process edges- add source_node_type & target_node_type

# %%
dfe = pd.merge(dfe, data[['url', 'node_type']], how='left', left_on='Source', right_on='url')[['Source', 'Label', 'Target', 'node_type']]
dfe.columns = ['Source', 'Label', 'Target', 'Source_Node_Type']
dfe.head()

dfe = pd.merge(dfe, data[['url', 'node_type']], how='left', left_on='Target', right_on='url')[['Source', 'Label', 'Target', 'Source_Node_Type', 'node_type']]
dfe.columns = ['Source', 'Label', 'Target', 'Source_Node_Type', 'Target_Node_Type']
dfe.head()
# Out:
#          Source            Label           Target Source_Node_Type  \
# 0  Faceless_Men        Season(s)         Season_2     Organization
# 1  Faceless_Men        Season(s)         Season_5     Organization
# 2  Faceless_Men        Season(s)         Season_6     Organization
# 3  Faceless_Men     Mentioned in  Valar_Morghulis     Organization
# 4  Faceless_Men  Notable Members   Jaqen_H%27ghar     Organization
#
#   Target_Node_Type
# 0           Season
# 1           Season
# 2           Season
# 3          Episode
# 4           Person

# %% [markdown]
# ## Store all entity data

# %%
data.to_csv('../Data/GOT_Entities.csv', index=False)

# %% [markdown]
# ## Analyse relationships

# %% [markdown]
# ### Remove unwanted relationships

# %%
unwanted_rels = ['Referred', 'Titles', 'Age', 'Portrayed by', 'Date', 'Date of birth', 'Family', 
                'Civilian Casualties', # only 6
                 'Date of Founding', #1
                 'Also known as', #6
                 'Date of founding', #6
                 'Date of dissolution', #10
                ]
dfe = dfe[(dfe.Label.apply(lambda x: x not in unwanted_rels))]
dfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13616 entries, 0 to 16503
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Source            13616 non-null  object
#  1   Label             13616 non-null  object
#  2   Target            13616 non-null  object
#  3   Source_Node_Type  13616 non-null  object
#  4   Target_Node_Type  13616 non-null  object
# dtypes: object(5)
# memory usage: 638.2+ KB

# %% [markdown]
# ### Type of Labels

# %%
dfe[['Source_Node_Type', 'Target_Node_Type', 'Label', 'Source']].groupby(by=['Label'], as_index=False).count().sort_values(by='Source', ascending=True)
# Out:
#          Label  Source_Node_Type  Target_Node_Type  Source
# 25     Habitat                 1                 1       1
# 34    Material                 1                 1       1
# 16         End                 2                 2       2
# 4    Beginning                 2                 2       2
# 61       Sigil                 3                 3       3
# ..         ...               ...               ...     ...
# 60    Siblings               753               753     753
# 41      Origin               782               782     782
# 14       Death              1025              1025    1025
# 58   Season(s)              1703              1703    1703
# 0   Allegiance              1706              1706    1706
#
# [69 rows x 4 columns]

# %% [markdown]
# ### Merge/Delete few Labels

# %%
dfe.loc[dfe.Label == 'Regional capital', 'Label'] = 'Capital'
dfe.loc[dfe.Label == 'Predecessors', 'Label'] = 'Predecessor'
dfe.loc[dfe.Label == 'Successors', 'Label'] = 'Successor'
dfe.loc[dfe.Label == 'Vassals', 'Label'] = 'Allegiance'

filter_remove_labels = (dfe.Label=='Habitat')|(dfe.Label=='Material')|(dfe.Label=='End')|(dfe.Label=='Beginning')|(dfe.Label=='Geography')|(dfe.Label=='Sigil')
dfe = dfe[~filter_remove_labels]

# %% [markdown]
# ### P2P relationships

# %%
dfe[(dfe.Source_Node_Type == 'Person') & (dfe.Target_Node_Type == 'Person')].Label.unique()
# Out:
# array(['Predecessor', 'Death', 'Father', 'Mother', 'Spouse', 'Siblings',
#        'Allegiance', 'Lovers', 'Successor', 'Children', 'Last seen',
#        'Appeared in', 'Death shown in episode'], dtype=object)

# %%
# dfe[(dfe.Source_Node_Type == 'Person') & (dfe.Target_Node_Type == 'Person') & (dfe.Label == 'Death shown in episode')]
# dfe[(dfe.Source_Node_Type == 'Person') & (dfe.Target_Node_Type == 'Person') & (dfe.Label == 'Last seen')]
# dfe[(dfe.Source_Node_Type == 'Person') & (dfe.Target_Node_Type == 'Person') & (dfe.Label == 'Appeared in')]

remove_filter = (dfe.Source_Node_Type == 'Person') & (dfe.Target_Node_Type == 'Person') & ((dfe.Label == 'Appeared in')|(dfe.Label == 'Last seen')|(dfe.Label == 'Death shown in episode'))

#drop these relationships
dfe = dfe[~remove_filter]

# %%
dfe[(dfe.Source_Node_Type == 'Person') & (dfe.Target_Node_Type == 'Person')].Label.unique()
# Out:
# array(['Predecessor', 'Death', 'Father', 'Mother', 'Spouse', 'Siblings',
#        'Allegiance', 'Lovers', 'Successor', 'Children'], dtype=object)

# %% [markdown]
# ### Relationships Created

# %%
## Combine relationships
dfe['Relation'] = dfe.Label

# %%
print('List of relatinship types:')
dfe.Relation.unique()
# Out:
# List of relatinship types:
# array(['Season(s)', 'Mentioned in', 'Notable Members', 'Former Members',
#        'Religion', 'Center', 'Location', 'Clergy', 'Allegiance', 'Leader',
#        'Founder', 'Appeared in', 'First seen', 'Predecessor', 'Last seen',
#        'Death', 'Death shown in episode', 'Culture', 'Conflict', 'Place',
#        'Outcome', 'Origin', 'Father', 'Mother', 'Spouse', 'Siblings',
#        'Battles', 'Rulers', 'Narrated by', 'Lovers', 'Successor',
#        'Children', 'Maker', 'Owner', 'Seat', 'Region', 'Lord', 'Capital',
#        'Cities', 'Towns', 'Castles', 'Species', 'Range', 'Ruler',
#        'Population', 'Heir', 'Ancestral weapon', 'Places of Note',
#        'Formerly', 'Places of note', 'Military', 'Institutions',
#        'Villages', 'Place of origin', 'Formed from', 'Cadet branches',
#        'Military strength', 'Premiere', 'Finale'], dtype=object)

# %%
dfe[['Source_Node_Type', 'Target_Node_Type', 'Relation', 'Source']].groupby(by=['Source_Node_Type', 'Target_Node_Type', 'Relation'], as_index=False).count().sort_values(by='Source', ascending=False)
# Out:
#     Source_Node_Type Target_Node_Type    Relation  Source
# 183           Person           Season   Season(s)    1418
# 151           Person            House  Allegiance     893
# 161           Person         Location      Origin     761
# 175           Person           Person    Siblings     753
# 179           Person       PersonType     Culture     500
# ..               ...              ...         ...     ...
# 186       PersonType            Event       Ruler       1
# 185       PersonType            Event    Location       1
# 191       PersonType         Location       Ruler       1
# 197       PersonType       PersonType       Ruler       1
# 206           Weapon     Organization       Owner       1
#
# [210 rows x 4 columns]

# %%
# Merge to same relationship for different labels

filter_seasons = (dfe.Label=='Season(s)')|(dfe.Label=='Appeared in')|(dfe.Label=='Mentioned in')|(dfe.Label=='First seen')|(dfe.Label=='Last seen')|(dfe.Label=='Death shown in episode')
dfe.loc[filter_seasons, ['Relation']] = 'SeenOrMentioned'

filter_member = (dfe.Label=='Notable Members')| (dfe.Label=='Former Members')
dfe.loc[filter_member, ['Relation']] = 'Membership'

dfe.loc[(dfe.Label == 'End'), ['Relation']] = 'Outcome'

filter_location = (dfe.Label=='Region')|(dfe.Label=='Seat')|(dfe.Label=='Origin')
dfe.loc[filter_location, ['Relation']] = 'AssociatedLocation'

# %%
dfe.Relation = dfe.Relation.str.replace(' ', '')

# %%
print('total edges: ')
print(dfe.count())

print('total unique edges (number converted to weight):')
print(dfe.groupby(by=['Source', 'Target'], as_index=False).count().count())
dfe.head()
# Out:
# total edges:
# Source              13600
# Label               13600
# Target              13600
# Source_Node_Type    13600
# Target_Node_Type    13600
# Relation            13600
# dtype: int64
# total unique edges (number converted to weight):
# Source              12741
# Target              12741
# Label               12741
# Source_Node_Type    12741
# Target_Node_Type    12741
# Relation            12741
# dtype: int64
#          Source            Label           Target Source_Node_Type  \
# 0  Faceless_Men        Season(s)         Season_2     Organization
# 1  Faceless_Men        Season(s)         Season_5     Organization
# 2  Faceless_Men        Season(s)         Season_6     Organization
# 3  Faceless_Men     Mentioned in  Valar_Morghulis     Organization
# 4  Faceless_Men  Notable Members   Jaqen_H%27ghar     Organization
#
#   Target_Node_Type         Relation
# 0           Season  SeenOrMentioned
# 1           Season  SeenOrMentioned
# 2           Season  SeenOrMentioned
# 3          Episode  SeenOrMentioned
# 4           Person       Membership

# %% [markdown]
# ## Generate Node files

# %%
script_template = ("LOAD CSV WITH HEADERS FROM {0} AS row\n"
                   "CREATE (n:{1})\n"
                   "SET n = row\n\n")

script_index_template = "CREATE INDEX ON :{0}(url)\n\n"

# %%
#Write nodes and edges to files
script = []
for label, df in data.groupby(by='node_type'):
    filepath = '../Outputs/Node_' + label + '.csv'
    df[['name', 'node_type', 'got_type', 'status', 'url']].to_csv(filepath, index=False)
    fullfilepath = '"file:///Node_' + label + '.csv"'
    script.append(script_template.format(fullfilepath, label))
    script.append(script_index_template.format(label))

# %% [markdown]
# ## Generate edge files

# %%
dfe.head()
# Out:
#          Source            Label           Target Source_Node_Type  \
# 0  Faceless_Men        Season(s)         Season_2     Organization
# 1  Faceless_Men        Season(s)         Season_5     Organization
# 2  Faceless_Men        Season(s)         Season_6     Organization
# 3  Faceless_Men     Mentioned in  Valar_Morghulis     Organization
# 4  Faceless_Men  Notable Members   Jaqen_H%27ghar     Organization
#
#   Target_Node_Type         Relation
# 0           Season  SeenOrMentioned
# 1           Season  SeenOrMentioned
# 2           Season  SeenOrMentioned
# 3          Episode  SeenOrMentioned
# 4           Person       Membership

# %%
script_edge_template = ("LOAD CSV WITH HEADERS FROM {0} AS row\n"
                   "MERGE (source:{1} {{url: row.Source}})\n"
                   "MERGE (target:{2} {{url: row.Target}})\n"
                   "CREATE (source)-[:{3}]->(target)\n\n")

# %%
for s, df in dfe.groupby(by=['Source_Node_Type', 'Target_Node_Type', 'Relation'], as_index=False):
    filepath = '../Outputs/Edge_' + s[0] + s[1] + s[2] + '.csv'
    df[['Source', 'Target', 'Relation', 'Label']].to_csv(filepath, index=False)
    fullfilepath = '"file:///Edge_' + s[0] + s[1] + s[2] + '.csv"'
    script.append(script_edge_template.format(fullfilepath, s[0], s[1], s[2]))

# %% [markdown]
# ## Store nodes & edges of graph

# %%
data[['name', 'node_type', 'got_type', 'status', 'url']].to_csv('../Data/nodes.csv', index=False)
dfe.to_csv('../Data/edges.csv', index=False)

# %%
f = open("Cypher_Script.txt", "w")
f.write('\n'.join(script))
# Out:
# 40082

# %% [markdown]
# ## Run queries for neo4j

# %%
uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "yusuf123"))

# %%
for query in script:
    with driver.session() as session:
        session.run(query)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:512, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, deadline, keep_alive, ssl_context)
#     511 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 512 s.connect(resolved_address)
#     513 s.settimeout(t)
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt_socket.py:329, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 try:
# --> 329     s = cls._connect_secure(
#     330         resolved_address,
#     331         tcp_timeout,
#     332         deadline,
#     333         keep_alive,
#     334         ssl_context,
#     335     )
#     336     agreed_version = s._handshake(resolved_address, deadline)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:523, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, deadline, keep_alive, ssl_context)
#     522 if isinstance(error, OSError):
# --> 523     raise ServiceUnavailable(
#     524         "Failed to establish connection to "
#     525         f"{resolved_address!r} (reason {error})"
#     526     ) from error
#     527 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[34], line 3
#       1 for query in script:
#       2     with driver.session() as session:
# ----> 3         session.run(query)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:305, in Session.run(self, query, parameters, **kwargs)
#     302     self._auto_result._buffer_all()
#     304 if not self._connection:
# --> 305     self._connect(self._config.default_access_mode)
#     306     assert self._connection is not None
#     307 cx = self._connection
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:126, in Session._connect(self, access_mode, **acquire_kwargs)
#     124     access_mode = self._config.default_access_mode
#     125 try:
# --> 126     super()._connect(
#     127         access_mode, auth=self._config.auth, **acquire_kwargs
#     128     )
#     129 except asyncio.CancelledError:
#     130     self._handle_cancellation(message="_connect")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\workspace.py:181, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)
#     178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#     180 acquire_kwargs_.update(acquire_kwargs)
# --> 181 self._connection = self._pool.acquire(**acquire_kwargs_)
#     182 if (
#     183     target_db.guessed
#     184     and not self._pinned_database
#    (...)
#     188     # support SSR.
#     189     # => we need to fall back to explicit home database resolution
#     190     log.debug(
#     191         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     192         "falling back to explicit home database resolution",
#     193     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_pool.py:678, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     671 deadline = acquisition_timeout_to_deadline(timeout)
#     672 log.debug(
#     673     "[#0000]  _: <POOL> acquire direct connection, "
#     674     "access_mode=%r, database=%r",
#     675     access_mode,
#     676     database,
#     677 )
# --> 678 return self._acquire(
#     679     self.address, auth, deadline, liveness_check_timeout, unprepared
#     680 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     413             raise ConnectionAcquisitionTimeoutError(
#     414                 "failed to obtain a connection from the pool within "
#     415                 f"{deadline.original_timeout!r}s (timeout)"
#     416             )
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
#     230     try:
# --> 231         connection = self.opener(
#     232             address, auth or self.pool_config.auth, deadline
#     233         )
#     234     except ServiceUnavailable:
#     235         self.deactivate(address)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_pool.py:638, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     637 def opener(addr, auth_manager, deadline):
# --> 638     return Bolt.open(
#     639         addr,
#     640         auth_manager=auth_manager,
#     641         deadline=deadline,
#     642         routing_context=None,
#     643         pool_config=pool_config,
#     644     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:368, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     365 if deadline is None:
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#     378 protocol_handlers = Bolt.protocol_handlers
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt_socket.py:380, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     378 else:
#     379     error_strs = "\n".join(map(str, errors))
# --> 380     raise ServiceUnavailable(
#     381         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     382         f"\n{error_strs}"
#     383     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
